# %% [markdown]
# # Homework 4: GAN and NAS
#
# ### Name: [Jihui.Sheng]
#
# ## In this assignment, you will:
#
# ## (1) run and understand the provided pytorch code for GAN;
# ## (2) read a NAS paper and answer the questions.
#
#
# ## Submission:
#
# * Convert the ipynb files to html files (**save the execution outputs and make sure the html file is generated properly**)
#
# * Compress and submit the ipynb and html files to Blackboard. Remember to name your html file with your name and ID.
# (When submitting: you will have one ipynb file and one html file for GAN section, and one ipynb file, i.e., this file, and one html file for the rest sections)
#
# * **Deadline: May 5**, 11:59:59 PM, Pacific time.
#
# * **Late policy**: your total points will be **$100 - \min( 10n, 80 )$** if you submit assignment $n$ days after the deadline.
# (If you have any difficulty in time schedule, please let me know.)
#
# * If you are more comfortable to use other libraries such as Keras and TensorFlow, you can change the code accordingly.
#
# * You may use [Google Colab](https://colab.research.google.com/) to get free access to GPUs
# (how to: Runtime --> Change runtime type --> Hardware accelerator --> GPU)
#
# ## Reference
# * GAN section follows [Dive into Deep Learning](https://d2l.ai/index.html), section [17.2](https://d2l.ai/chapter_generative-adversarial-networks/dcgan.html).

# %% [markdown]
# # 1. GAN
#
# 1) Please use the provided code in [Dive into Deep Learning](https://d2l.ai/index.html), section [17.2](https://d2l.ai/chapter_generative-adversarial-networks/dcgan.html) deep convolutional generative adversarial networks .
#
# 2) Choose a library (MXNET or PYTORCH) on the page
#
# 3) Click "COLAB\[MXNET\]" or "COLAB\[PYTORCH\]" (see [this section](https://d2l.ai/chapter_installation/index.html) for the installation of the used libraries MXNET or PYTORCH if you need to install them). Or access these jupyter notebook directly at [MXNET](https://colab.research.google.com/github/d2l-ai/d2l-en-colab/blob/master/chapter_generative-adversarial-networks/dcgan.ipynb) or [PYTORCH](https://colab.research.google.com/github/d2l-ai/d2l-pytorch-colab/blob/master/chapter_generative-adversarial-networks/dcgan.ipynb)
#
# 4) (30 points) Run all code for training a GAN on the pokemon dataset with Colab and save the  execution outputs
#
# 5) (30 points) Complete exercises 1 in [Section 17.2.6](https://d2l.ai/chapter_generative-adversarial-networks/dcgan.html#exercises): what if use standard ReLU activation rather than leaky ReLU.
# You may add your code at the end of the ipynb file.
#
# Hint for pytorch:
# Generator uses ReLU as the activation function, so you may follow the generator's code to replace leakyReLU with ReLU in discriminator.
# You may also find the document of [torch.nn.LeakyReLU](https://pytorch.org/docs/stable/generated/torch.nn.LeakyReLU.html#torch.nn.LeakyReLU) and [torch.nn.ReLU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html#torch.nn.ReLU) to see the full description of the interfaces.
#
# 6) Download the GAN ipynb file and convert it to html format.

# %%
# !pip install torch torchvision
# !pip install -U d2l
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: torch in c:\users\jihui\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: torchvision in c:\users\jihui\anaconda3\lib\site-packages (0.8.2)
# Requirement already satisfied: typing_extensions in c:\users\jihui\anaconda3\lib\site-packages (from torch) (3.7.4.3)
# Requirement already satisfied: numpy in c:\users\jihui\anaconda3\lib\site-packages (from torch) (1.19.2)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\jihui\anaconda3\lib\site-packages (from torchvision) (8.0.1)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting d2l
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/69/62/a53c44bf0d076df002e4ab16f0cfaf5c31c1b158d0ec88db1494dfbfa5af/d2l-0.16.3-py3-none-any.whl (77 kB)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\jihui\anaconda3\lib\site-packages (from d2l) (1.19.2)
# Requirement already satisfied, skipping upgrade: jupyter in c:\users\jihui\anaconda3\lib\site-packages (from d2l) (1.0.0)
# Requirement already satisfied, skipping upgrade: requests in c:\users\jihui\anaconda3\lib\site-packages (from d2l) (2.24.0)
# Requirement already satisfied, skipping upgrade: pandas in c:\users\jihui\anaconda3\lib\site-packages (from d2l) (1.1.3)
# Requirement already satisfied, skipping upgrade: matplotlib in c:\users\jihui\anaconda3\lib\site-packages (from d2l) (3.3.2)
# Requirement already satisfied, skipping upgrade: ipywidgets in c:\users\jihui\anaconda3\lib\site-packages (from jupyter->d2l) (7.5.1)
# Requirement already satisfied, skipping upgrade: jupyter-console in c:\users\jihui\anaconda3\lib\site-packages (from jupyter->d2l) (6.2.0)
# Requirement already satisfied, skipping upgrade: notebook in c:\users\jihui\anaconda3\lib\site-packages (from jupyter->d2l) (6.1.4)
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\jihui\anaconda3\lib\site-packages (from jupyter->d2l) (6.0.7)
# Requirement already satisfied, skipping upgrade: qtconsole in c:\users\jihui\anaconda3\lib\site-packages (from jupyter->d2l) (4.7.7)
# Requirement already satisfied, skipping upgrade: ipykernel in c:\users\jihui\anaconda3\lib\site-packages (from jupyter->d2l) (5.3.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\jihui\anaconda3\lib\site-packages (from requests->d2l) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\jihui\anaconda3\lib\site-packages (from requests->d2l) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\jihui\anaconda3\lib\site-packages (from requests->d2l) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jihui\anaconda3\lib\site-packages (from requests->d2l) (1.25.11)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\jihui\anaconda3\lib\site-packages (from pandas->d2l) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\jihui\anaconda3\lib\site-packages (from pandas->d2l) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\jihui\anaconda3\lib\site-packages (from matplotlib->d2l) (1.3.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\jihui\anaconda3\lib\site-packages (from matplotlib->d2l) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in c:\users\jihui\anaconda3\lib\site-packages (from matplotlib->d2l) (2.4.7)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in c:\users\jihui\anaconda3\lib\site-packages (from matplotlib->d2l) (8.0.1)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in c:\users\jihui\anaconda3\lib\site-packages (from ipywidgets->jupyter->d2l) (3.5.1)
# Requirement already satisfied, skipping upgrade: ipython>=4.0.0; python_version >= "3.3" in c:\users\jihui\anaconda3\lib\site-packages (from ipywidgets->jupyter->d2l) (7.19.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in c:\users\jihui\anaconda3\lib\site-packages (from ipywidgets->jupyter->d2l) (5.0.5)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\jihui\anaconda3\lib\site-packages (from ipywidgets->jupyter->d2l) (5.0.8)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jihui\anaconda3\lib\site-packages (from jupyter-console->jupyter->d2l) (3.0.8)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\jihui\anaconda3\lib\site-packages (from jupyter-console->jupyter->d2l) (2.7.2)
# Requirement already satisfied, skipping upgrade: jupyter-client in c:\users\jihui\anaconda3\lib\site-packages (from jupyter-console->jupyter->d2l) (6.1.7)
# Requirement already satisfied, skipping upgrade: tornado>=5.0 in c:\users\jihui\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (6.0.4)
# Requirement already satisfied, skipping upgrade: jupyter-core>=4.6.1 in c:\users\jihui\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (4.6.3)
# Requirement already satisfied, skipping upgrade: argon2-cffi in c:\users\jihui\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (20.1.0)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.3 in c:\users\jihui\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (0.9.1)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in c:\users\jihui\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (19.0.2)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\jihui\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (0.8.0)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\jihui\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (1.5.0)
# Requirement already satisfied, skipping upgrade: jinja2 in c:\users\jihui\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (2.11.2)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\jihui\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (0.2.0)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\jihui\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.6.0)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\jihui\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (1.4.3)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\jihui\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (3.2.1)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\jihui\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.3)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in c:\users\jihui\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.8.4)
# Requirement already satisfied, skipping upgrade: nbclient<0.6.0,>=0.5.0 in c:\users\jihui\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.5.1)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\jihui\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.4.4)
# Requirement already satisfied, skipping upgrade: jupyterlab-pygments in c:\users\jihui\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.1.2)
# Requirement already satisfied, skipping upgrade: qtpy in c:\users\jihui\anaconda3\lib\site-packages (from qtconsole->jupyter->d2l) (1.9.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\jihui\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->d2l) (1.15.0)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in c:\users\jihui\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->d2l) (50.3.1.post20201107)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\jihui\appdata\roaming\python\python38\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->d2l) (0.4.3)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\jihui\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->d2l) (0.7.5)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\jihui\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->d2l) (0.17.1)
# Requirement already satisfied, skipping upgrade: decorator in c:\users\jihui\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->d2l) (4.4.2)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\jihui\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->d2l) (0.2.0)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\jihui\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->d2l) (3.2.0)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\jihui\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->d2l) (0.2.5)
# Requirement already satisfied, skipping upgrade: pywin32>=1.0; sys_platform == "win32" in c:\users\jihui\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook->jupyter->d2l) (227)
# Requirement already satisfied, skipping upgrade: cffi>=1.0.0 in c:\users\jihui\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->d2l) (1.14.3)
# Requirement already satisfied, skipping upgrade: pywinpty>=0.5 in c:\users\jihui\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->d2l) (0.5.7)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\jihui\anaconda3\lib\site-packages (from jinja2->notebook->jupyter->d2l) (1.1.1)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\jihui\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->d2l) (20.4)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\jihui\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->d2l) (0.5.1)
# Requirement already satisfied, skipping upgrade: async-generator in c:\users\jihui\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->d2l) (1.10)
# Requirement already satisfied, skipping upgrade: nest-asyncio in c:\users\jihui\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->d2l) (1.4.2)
# Requirement already satisfied, skipping upgrade: parso<0.8.0,>=0.7.0 in c:\users\jihui\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->d2l) (0.7.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in c:\users\jihui\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->d2l) (0.17.3)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in c:\users\jihui\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->d2l) (20.3.0)
# Requirement already satisfied, skipping upgrade: pycparser in c:\users\jihui\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->d2l) (2.20)
# Installing collected packages: d2l
#   Attempting uninstall: d2l
#     Found existing installation: d2l 0.16.2
#     Uninstalling d2l-0.16.2:
#       Successfully uninstalled d2l-0.16.2
# Successfully installed d2l-0.16.3

# %%
import warnings
import torch
import torchvision
from torch import nn
from d2l import torch as d2l

#@save
d2l.DATA_HUB['pokemon'] = (d2l.DATA_URL + 'pokemon.zip',
                           'c065c0e2593b8b161a2d7873e42418bf6a21106c')

data_dir = d2l.download_extract('pokemon')
pokemon = torchvision.datasets.ImageFolder(data_dir)

# %%
batch_size = 256
transformer = torchvision.transforms.Compose([
    torchvision.transforms.Resize((64, 64)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(0.5, 0.5)])
pokemon.transform = transformer
data_iter = torch.utils.data.DataLoader(
    pokemon, batch_size=batch_size, shuffle=True,
    num_workers=d2l.get_dataloader_workers())

# %%
warnings.filterwarnings('ignore')
d2l.set_figsize((4, 4))
for X, y in data_iter:
    imgs = X[0:20, :, :, :].permute(0, 2, 3, 1) / 2 + 0.5
    d2l.show_images(imgs, num_rows=4, num_cols=5)
    break

# %%
class G_block(nn.Module):
    def __init__(self, out_channels, in_channels=3, kernel_size=4, strides=2,
                 padding=1, **kwargs):
        super(G_block, self).__init__(**kwargs)
        self.conv2d_trans = nn.ConvTranspose2d(in_channels, out_channels,
                                               kernel_size, strides, padding,
                                               bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU()

    def forward(self, X):
        return self.activation(self.batch_norm(self.conv2d_trans(X)))

# %%
x = torch.zeros((2, 3, 16, 16))
g_blk = G_block(20)
g_blk(x).shape
# Out:
# torch.Size([2, 20, 32, 32])

# %%
x = torch.zeros((2, 3, 1, 1))
g_blk = G_block(20, strides=1, padding=0)
g_blk(x).shape
# Out:
# torch.Size([2, 20, 4, 4])

# %%
n_G = 64
net_G = nn.Sequential(
    G_block(in_channels=100, out_channels=n_G * 8, strides=1,
            padding=0),  # Output: (64 * 8, 4, 4)
    G_block(in_channels=n_G * 8,
            out_channels=n_G * 4),  # Output: (64 * 4, 8, 8)
    G_block(in_channels=n_G * 4,
            out_channels=n_G * 2),  # Output: (64 * 2, 16, 16)
    G_block(in_channels=n_G * 2, out_channels=n_G),  # Output: (64, 32, 32)
    nn.ConvTranspose2d(in_channels=n_G, out_channels=3,
                       kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh())  # Output: (3, 64, 64)

# %%
x = torch.zeros((1, 100, 1, 1))
net_G(x).shape
# Out:
# torch.Size([1, 3, 64, 64])

# %%
alphas = [0, .2, .4, .6, .8, 1]
x = torch.arange(-2, 1, 0.1)
Y = [nn.LeakyReLU(alpha)(x).detach().numpy() for alpha in alphas]
d2l.plot(x.detach().numpy(), Y, 'x', 'y', alphas)

# %%
class D_block(nn.Module):
    def __init__(self, out_channels, in_channels=3, kernel_size=4, strides=2,
                 padding=1, alpha=0.2, **kwargs):
        super(D_block, self).__init__(**kwargs)
        self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size,
                                strides, padding, bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.LeakyReLU(alpha, inplace=True)

    def forward(self, X):
        return self.activation(self.batch_norm(self.conv2d(X)))

# %%
x = torch.zeros((2, 3, 16, 16))
d_blk = D_block(20)
d_blk(x).shape
# Out:
# torch.Size([2, 20, 8, 8])

# %%
n_D = 64
net_D = nn.Sequential(
    D_block(n_D),  # Output: (64, 32, 32)
    D_block(in_channels=n_D,
            out_channels=n_D * 2),  # Output: (64 * 2, 16, 16)
    D_block(in_channels=n_D * 2,
            out_channels=n_D * 4),  # Output: (64 * 4, 8, 8)
    D_block(in_channels=n_D * 4,
            out_channels=n_D * 8),  # Output: (64 * 8, 4, 4)
    nn.Conv2d(in_channels=n_D * 8, out_channels=1, kernel_size=4,
              bias=False))  # Output: (1, 1, 1)

# %%
x = torch.zeros((1, 3, 64, 64))
net_D(x).shape
# Out:
# torch.Size([1, 1, 1, 1])

# %%
def train(net_D, net_G, data_iter, num_epochs, lr, latent_dim,
          device=d2l.try_gpu()):
    loss = nn.BCEWithLogitsLoss(reduction='sum')
    for w in net_D.parameters():
        nn.init.normal_(w, 0, 0.02)
    for w in net_G.parameters():
        nn.init.normal_(w, 0, 0.02)
    net_D, net_G = net_D.to(device), net_G.to(device)
    trainer_hp = {'lr': lr, 'betas': [0.5, 0.999]}
    trainer_D = torch.optim.Adam(net_D.parameters(), **trainer_hp)
    trainer_G = torch.optim.Adam(net_G.parameters(), **trainer_hp)
    animator = d2l.Animator(xlabel='epoch', ylabel='loss',
                            xlim=[1, num_epochs], nrows=2, figsize=(5, 5),
                            legend=['discriminator', 'generator'])
    animator.fig.subplots_adjust(hspace=0.3)
    for epoch in range(1, num_epochs + 1):
        # Train one epoch
        timer = d2l.Timer()
        metric = d2l.Accumulator(3)  # loss_D, loss_G, num_examples
        for X, _ in data_iter:
            batch_size = X.shape[0]
            Z = torch.normal(0, 1, size=(batch_size, latent_dim, 1, 1))
            X, Z = X.to(device), Z.to(device)
            metric.add(d2l.update_D(X, Z, net_D, net_G, loss, trainer_D),
                       d2l.update_G(Z, net_D, net_G, loss, trainer_G),
                       batch_size)
        # Show generated examples
        Z = torch.normal(0, 1, size=(21, latent_dim, 1, 1), device=device)
        # Normalize the synthetic data to N(0, 1)
        fake_x = net_G(Z).permute(0, 2, 3, 1) / 2 + 0.5
        imgs = torch.cat([
            torch.cat([fake_x[i * 7 + j].cpu().detach()
                       for j in range(7)], dim=1)
            for i in range(len(fake_x) // 7)], dim=0)
        animator.axes[1].cla()
        animator.axes[1].imshow(imgs)
        # Show the losses
        loss_D, loss_G = metric[0] / metric[2], metric[1] / metric[2]
        animator.add(epoch, (loss_D, loss_G))
    print(f'loss_D {loss_D:.3f}, loss_G {loss_G:.3f}, '
          f'{metric[2] / timer.stop():.1f} examples/sec on {str(device)}')

# %%
latent_dim, lr, num_epochs = 100, 0.005, 20
train(net_D, net_G, data_iter, num_epochs, lr, latent_dim)
# Out:
# loss_D 0.073, loss_G 7.872, 278.3 examples/sec on cuda:0

# %% [markdown]
# # 2. NAS

# %% [markdown]
# Read reference paper \[1\] (at [this link](https://arxiv.org/pdf/1707.04873.pdf)) on NAS. and Answer the following two questions (use plain lanugage to describe your answer and no need to include too many techniques)
#
# Hint: you may not read the entire paper. Instead, read the first paragraph of subsection "Net2Deeper Actor" on Page 3 (You may search the key word "Net2Deeper Actor" on the pdf file to find the subsection on page 3). To get better understanding towards Net2Deeper Actor, you may also read the subsection "Net2Wider Actor" on Page 3.
#
# Q1 (20 points): How to initialize the kernel of a new convolutional layer in the Net2Deeper actor?
#
# **Answer:**

# %%
#  For the new convolutional layer, set the kernel to the identity filter, and for the new fully connected layer, set the weight matrix to the identity matrix.
#  If the Net2Deeper actor decides to insert a new layer after the fully connected layer or the final global average pooling layer, the new layer will be restricted
# to the fully connected layer, otherwise it must be a convolutional layer.

# %% [markdown]
# Q2 (20 points): How could we widen this new convolutional layer?
#
# **Answer:**

# %%
#  Net2WiderNet operation allows replacing a layer with a wider layer, which means that while preserving functionality, 
# （more units are used for the fully connected layer, or) more filters are used for the convolutional layer

# %% [markdown]
# Reference:
#
# \[1\] Cai, Han, Tianyao Chen, Weinan Zhang, Yong Yu, and Jun Wang. "Efficient architecture search by network transformation." In Proceedings of the AAAI Conference on Artificial Intelligence, vol. 32, no. 1. 2018.

# %%
#1.5
import warnings
import torch
import torchvision
from torch import nn
from d2l import torch as d2l

#@save
d2l.DATA_HUB['pokemon'] = (d2l.DATA_URL + 'pokemon.zip',
                           'c065c0e2593b8b161a2d7873e42418bf6a21106c')

data_dir = d2l.download_extract('pokemon')
pokemon = torchvision.datasets.ImageFolder(data_dir)

batch_size = 256
transformer = torchvision.transforms.Compose([
    torchvision.transforms.Resize((64, 64)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(0.5, 0.5)])
pokemon.transform = transformer
data_iter = torch.utils.data.DataLoader(
    pokemon, batch_size=batch_size, shuffle=True,
    num_workers=d2l.get_dataloader_workers())

warnings.filterwarnings('ignore')
d2l.set_figsize((4, 4))
for X, y in data_iter:
    imgs = X[0:20, :, :, :].permute(0, 2, 3, 1) / 2 + 0.5
    d2l.show_images(imgs, num_rows=4, num_cols=5)
    break
    
class G_block(nn.Module):
    def __init__(self, out_channels, in_channels=3, kernel_size=4, strides=2,
                 padding=1, **kwargs):
        super(G_block, self).__init__(**kwargs)
        self.conv2d_trans = nn.ConvTranspose2d(in_channels, out_channels,
                                               kernel_size, strides, padding,
                                               bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.ReLU()

    def forward(self, X):
        return self.activation(self.batch_norm(self.conv2d_trans(X)))
    
x = torch.zeros((2, 3, 16, 16))
g_blk = G_block(20)
g_blk(x).shape

x = torch.zeros((2, 3, 1, 1))
g_blk = G_block(20, strides=1, padding=0)
g_blk(x).shape

n_G = 64
net_G = nn.Sequential(
    G_block(in_channels=100, out_channels=n_G * 8, strides=1,
            padding=0),  # Output: (64 * 8, 4, 4)
    G_block(in_channels=n_G * 8,
            out_channels=n_G * 4),  # Output: (64 * 4, 8, 8)
    G_block(in_channels=n_G * 4,
            out_channels=n_G * 2),  # Output: (64 * 2, 16, 16)
    G_block(in_channels=n_G * 2, out_channels=n_G),  # Output: (64, 32, 32)
    nn.ConvTranspose2d(in_channels=n_G, out_channels=3,
                       kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh())  # Output: (3, 64, 64)

x = torch.zeros((1, 100, 1, 1))
net_G(x).shape

alphas = [0, .2, .4, .6, .8, 1]
x = torch.arange(-2, 1, 0.1)
Y = [nn.ReLU(alpha)(x).detach().numpy() for alpha in alphas]
d2l.plot(x.detach().numpy(), Y, 'x', 'y', alphas)

class D_block(nn.Module):
    def __init__(self, out_channels, in_channels=3, kernel_size=4, strides=2,
                 padding=1, alpha=0.2, **kwargs):
        super(D_block, self).__init__(**kwargs)
        self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size,
                                strides, padding, bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.activation = nn.LeakyReLU(alpha, inplace=True)

    def forward(self, X):
        return self.activation(self.batch_norm(self.conv2d(X)))
    
x = torch.zeros((2, 3, 16, 16))
d_blk = D_block(20)
d_blk(x).shape

n_D = 64
net_D = nn.Sequential(
    D_block(n_D),  # Output: (64, 32, 32)
    D_block(in_channels=n_D,
            out_channels=n_D * 2),  # Output: (64 * 2, 16, 16)
    D_block(in_channels=n_D * 2,
            out_channels=n_D * 4),  # Output: (64 * 4, 8, 8)
    D_block(in_channels=n_D * 4,
            out_channels=n_D * 8),  # Output: (64 * 8, 4, 4)
    nn.Conv2d(in_channels=n_D * 8, out_channels=1, kernel_size=4,
              bias=False))  # Output: (1, 1, 1)

x = torch.zeros((1, 3, 64, 64))
net_D(x).shape

def train(net_D, net_G, data_iter, num_epochs, lr, latent_dim,
          device=d2l.try_gpu()):
    loss = nn.BCEWithLogitsLoss(reduction='sum')
    for w in net_D.parameters():
        nn.init.normal_(w, 0, 0.02)
    for w in net_G.parameters():
        nn.init.normal_(w, 0, 0.02)
    net_D, net_G = net_D.to(device), net_G.to(device)
    trainer_hp = {'lr': lr, 'betas': [0.5, 0.999]}
    trainer_D = torch.optim.Adam(net_D.parameters(), **trainer_hp)
    trainer_G = torch.optim.Adam(net_G.parameters(), **trainer_hp)
    animator = d2l.Animator(xlabel='epoch', ylabel='loss',
                            xlim=[1, num_epochs], nrows=2, figsize=(5, 5),
                            legend=['discriminator', 'generator'])
    animator.fig.subplots_adjust(hspace=0.3)
    for epoch in range(1, num_epochs + 1):
        # Train one epoch
        timer = d2l.Timer()
        metric = d2l.Accumulator(3)  # loss_D, loss_G, num_examples
        for X, _ in data_iter:
            batch_size = X.shape[0]
            Z = torch.normal(0, 1, size=(batch_size, latent_dim, 1, 1))
            X, Z = X.to(device), Z.to(device)
            metric.add(d2l.update_D(X, Z, net_D, net_G, loss, trainer_D),
                       d2l.update_G(Z, net_D, net_G, loss, trainer_G),
                       batch_size)
        # Show generated examples
        Z = torch.normal(0, 1, size=(21, latent_dim, 1, 1), device=device)
        # Normalize the synthetic data to N(0, 1)
        fake_x = net_G(Z).permute(0, 2, 3, 1) / 2 + 0.5
        imgs = torch.cat([
            torch.cat([fake_x[i * 7 + j].cpu().detach()
                       for j in range(7)], dim=1)
            for i in range(len(fake_x) // 7)], dim=0)
        animator.axes[1].cla()
        animator.axes[1].imshow(imgs)
        # Show the losses
        loss_D, loss_G = metric[0] / metric[2], metric[1] / metric[2]
        animator.add(epoch, (loss_D, loss_G))
    print(f'loss_D {loss_D:.3f}, loss_G {loss_G:.3f}, '
          f'{metric[2] / timer.stop():.1f} examples/sec on {str(device)}')
    
latent_dim, lr, num_epochs = 100, 0.005, 20
train(net_D, net_G, data_iter, num_epochs, lr, latent_dim)
# Out:
# loss_D 0.126, loss_G 5.917, 278.0 examples/sec on cuda:0

# %%
# Neurons may always output negative values. Since the gradient of ReLU is 0, no progress can be made.
